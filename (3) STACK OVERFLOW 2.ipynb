# %%
import pandas as pd

# %%
df3=pd.read_csv("survey_results_public.csv",index_col=[0])

# %%
schema=pd.read_csv("survey_results_schema.csv",index_col=[0])

# %%
schema
# Out:
#                                                                                                      QuestionText
# Column
# Respondent                                 Randomized respondent ID number (not in order of survey response time)
# MainBranch    Which of the following options best describes you today? Here, by "developer" we mean "someone w...
# Hobbyist                                                                                  Do you code as a hobby?
# OpenSourcer                                                           How often do you contribute to open source?
# OpenSource                                       How do you feel about the quality of open source software (OSS)?
# ...                                                                                                           ...
# Sexuality     Which of the following do you currently identify as? Please select all that apply. If you prefer...
# ...

# %%
df3
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
vba=df3["LanguageWorkedWith"].str.contains("VBA",na=False)

# %%
vba
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
pd.options.display.max_colwidth=100

# %%
df3.loc[vba,"LanguageWorkedWith"]
# Out:
# Respondent
# 5                                                                C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 16                                               Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 26                 Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScript;PHP;Python;Ruby;SQL;Swift;TypeScript;VBA
# 61                                                             C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 62           Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Ruby;SQL;TypeScript;VBA
#                                                         ...
# 75103                                                                                               Java;VBA
# 78741    Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojure;Dart;Elixir;Erlang;F#;Go;HTML/CSS;Java;JavaScrip...
# 79795                                                                   Bash/Shell/PowerShell;Python;SQL;VBA
# ...

# %%
flask=df3["WebFrameWorkedWith"].str.contains("Flask",na=False)

# %%
flask
# Out:
# Respondent
# 1         True
# 2        False
# 3        False
# 4        False
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: WebFrameWorkedWith, Length: 88883, dtype: bool

# %%
pd.options.display.max_colwidth=100

# %%
df3.loc[flask,"WebFrameWorkedWith"]
# Out:
# Respondent
# 1                                                                                               Django;Flask
# 5                                                                Django;Express;Flask;jQuery;React.js;Spring
# 8                                                                              Express;Flask;React.js;Spring
# 10                                                    Angular/Angular.js;ASP.NET;Django;Express;Flask;jQuery
# 21                                                                                    Django;Flask;Other(s):
#                                                         ...
# 75974                                                                                 Express;Flask;React.js
# 78741    Angular/Angular.js;ASP.NET;Django;Drupal;Express;Flask;jQuery;Laravel;React.js;Ruby on Rails;Spr...
# 79798                                                                                    Django;Flask;jQuery
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith', 'DevEnviron', 'OpSys',
#        'Containers', 'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson',
# ...

# %%
schema.sort_index(inplace=True)

# %%
schema
# Out:
#                                                                                                       QuestionText
# Column
# Age                   What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# Age1stCode     At what age did you write your first line of code or program? (E.g., webpage, Hello World, Scrat...
# BetterLife                              Do you think people born today will have a better life than their parents?
# BlockchainIs                                                  Blockchain / cryptocurrency technology is primarily:
# BlockchainOrg                       How is your organization thinking about or implementing blockchain technology?
# ...                                                                                                            ...
# WorkPlan                                                                   How structured or planned is your work?
# ...

# %%
df4=df3.copy()

# %%
df3["ITperson"]
# Out:
# Respondent
# 1        Fortunately, someone else has that title
# 2                                             Yes
# 3                                             Yes
# 4                                            SIGH
# 5                                        Also Yes
#                            ...
# 88377                                         Yes
# 88601                                         NaN
# 88802                                         NaN
# 88816                                         NaN
# 88863                                    Also Yes
# Name: ITperson, Length: 88883, dtype: object

# %%
schema.loc['MiscTechDesireNextYear',"QuestionText"]
# Out:
# 'Which of the following other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)'

# %%
df3.drop(['MiscTechDesireNextYear'],inplace=True,axis=1)

# %%
pd.set_option("display.max_columns",85)

# %%
df3
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# ...                                                                                   ...
# 88377                                                                                 NaN
# 88601                                                                                 NaN
# 88802                                                                                 NaN
# ...

# %%
feat_to_remove=['LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith']

# %%
df3.drop(feat_to_remove,axis=1,inplace=True)

# %%
df3
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# ...                                                                                   ...
# 88377                                                                                 NaN
# 88601                                                                                 NaN
# 88802                                                                                 NaN
# ...

# %%
df3.loc[1000]
# Out:
# MainBranch                                                       I am a developer by profession
# Hobbyist                                                                                    Yes
# OpenSourcer                                  Less than once a month but more than once per year
# OpenSource      OSS is, on average, of HIGHER quality than proprietary / closed source software
# Employment                                                                   Employed part-time
#                                                      ...
# Sexuality                                                               Straight / Heterosexual
# Ethnicity                                                          White or of European descent
# Dependents                                                                                   No
# SurveyLength                                                              Appropriate in length
# ...

# %%
df3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'DatabaseDesireNextYear',
#        'PlatformWorkedWith', 'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith', 'DevEnviron', 'OpSys',
#        'Containers', 'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson',
#        'OffOn', 'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
# ...

# %%
rows_to_remove=df3.loc[4:10,:]
rows_to_remove
# Out:
#                                                                                MainBranch  \
# Respondent
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# 6           I am not primarily a developer, but I write code sometimes as part of my work
# 7                                                          I am a developer by profession
# 8                                                             I code primarily as a hobby
# 9                                                          I am a developer by profession
# 10                                                         I am a developer by profession
#
#            Hobbyist                 OpenSourcer  \
# Respondent
# 4                No                       Never
# 5               Yes  Once a month or more often
# 6               Yes                       Never
# ...

# %%
df3.drop(rows_to_remove,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df3.drop(rows_to_remove,axis=0,inplace=True)
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\hello world\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df3.drop([17,18,19,20],axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df3.drop([17,18,19,20],axis=0,inplace=True)
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\hello world\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df3
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 11                                                            I code primarily as a hobby
# 12                                                 I am a student who is learning to code
# ...                                                                                   ...
# 88377                                                                                 NaN
# 88601                                                                                 NaN
# 88802                                                                                 NaN
# ...

# %%
pd.set_option("display.min_rows",40)

# %%
df3
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 11                                                            I code primarily as a hobby
# 12                                                 I am a student who is learning to code
# 16                                                         I am a developer by profession
# 21                                                            I code primarily as a hobby
# 22                                                         I am a developer by profession
# 23                                                         I am a developer by profession
# ...

# %%
col_to_remove=['MainBranch','Hobbyist','OpenSourcer']

# %%
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8632\2387837935.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df3.drop('MainBranch','Hobbyist','OpenSourcer',axis=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df3.drop('MainBranch','Hobbyist','OpenSourcer',axis=1)
#
# File C:\hello world\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df3.drop(df3.loc[60:70,:].index,axis=0)
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 11                                                            I code primarily as a hobby
# 12                                                 I am a student who is learning to code
# 16                                                         I am a developer by profession
# 21                                                            I code primarily as a hobby
# 22                                                         I am a developer by profession
# 23                                                         I am a developer by profession
# ...

# %%
df4
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# 6           I am not primarily a developer, but I write code sometimes as part of my work
# 7                                                          I am a developer by profession
# 8                                                             I code primarily as a hobby
# 9                                                          I am a developer by profession
# ...

# %%
df4.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df4.columns
#
# File C:\hello world\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
df5=df4.copy()

# %%
df4
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16        True
# 17       False
# 18       False
# 19       False
# 20       False
#          ...
# 85961    False
# 86012    False
# 86566    False
# 86638     True
# 86806    False
# 86980    False
# 86999    False
# 87352    False
# 87386    False
# 87739    False
# 88062    False
# 88076    False
# 88182    False
# 88212    False
# 88282    False
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df4["LanguageWorkedWith"].str.contains("VBA",na=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\hello world\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\hello world\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\hello world\lib\site-packages\pandas\_libs\index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df4["LanguageWorkedWith"].str.contains("VBA",na=False)
#
# ...

# %%
df4[fil]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df4[fil]
#
# NameError: name 'fil' is not defined

# %%
df4=pd.read_csv("survey_results_public.csv",index_col=[0])

# %%
df4
# Out:
#                                                                                MainBranch  \
# Respondent
# 1                                                  I am a student who is learning to code
# 2                                                  I am a student who is learning to code
# 3           I am not primarily a developer, but I write code sometimes as part of my work
# 4                                                          I am a developer by profession
# 5                                                          I am a developer by profession
# 6           I am not primarily a developer, but I write code sometimes as part of my work
# 7                                                          I am a developer by profession
# 8                                                             I code primarily as a hobby
# 9                                                          I am a developer by profession
# ...

# %%
df5=df4.copy()

# %%
fil=df4["LanguageWorkedWith"].str.contains("VBA",na=False)

# %%
df4.loc[fil,["LanguageWorkedWith","Country"]]
# Out:
#                                                                                              LanguageWorkedWith  \
# Respondent
# 5                                                                   C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 16                                                  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 26                    Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScript;PHP;Python;Ruby;SQL;Swift;TypeScript;VBA
# 61                                                                C++;C#;HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# 62              Bash/Shell/PowerShell;C++;Go;HTML/CSS;Java;JavaScript;Kotlin;PHP;Python;Ruby;SQL;TypeScript;VBA
# 67                                                             C;C#;HTML/CSS;Java;JavaScript;PHP;Python;SQL;VBA
# 71                                                                       HTML/CSS;JavaScript;PHP;Python;SQL;VBA
# ...

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4.rename(columns={"ConvertedComp":"SalaryUSD"},inplace=True)

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote', 'WorkLoc',
#        'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests', 'PurchaseHow',
#        'PurchaseWhat', 'LanguageWorkedWith', 'LanguageDesireNextYear',
#        'DatabaseWorkedWith', 'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4.rename(columns={"WorkLoc":"WorkingLocation","DevType":"DeveloperType"},inplace=True)

# %%
df4.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DeveloperType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq', 'SalaryUSD',
#        'WorkWeekHrs', 'WorkPlan', 'WorkChallenge', 'WorkRemote',
#        'WorkingLocation', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df4["CurrencySymbol"].nunique()
# Out:
# 143

# %%
df4["Hobbyist"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df4["Hobbyist"]=df4["Hobbyist"].map({"Yes":True,"No":False})

# %%
df4["Hobbyist"].unique()
# Out:
# array([ True, False])

# %%
df4["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
df4["Age1stCode"].map({"Younger than 5 years":5,"Older than 85":85})
# Out:
# Respondent
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
#         ...
# 85961    NaN
# 86012    NaN
# 86566    NaN
# 86638    NaN
# 86806    NaN
# 86980    NaN
# 86999    NaN
# 87352    NaN
# 87386    NaN
# 87739    NaN
# 88062    NaN
# 88076    NaN
# 88182    5.0
# 88212    NaN
# 88282    NaN
# 88377    NaN
# 88601    NaN
# 88802    NaN
# 88816    NaN
# 88863    NaN
# Name: Age1stCode, Length: 88883, dtype: float64

# %%
df4["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
df4["Age1stCode"]=df4["Age1stCode"].replace("Younger than 5 years",5)

# %%
df4["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 5, '33', '25', '26', '39', '36', '38', '28', '31',
#        'Older than 85', '32', '37', '50', '65', '42', '34', '40', '67',
#        '43', '44', '60', '46', '45', '49', '51', '41', '55', '83', '48',
#        '53', '54', '47', '56', '79', '61', '68', '77', '66', '52', '80',
#        '62', '84', '57', '58', '63'], dtype=object)

# %%
df4["Age1stCode"]=df4["Age1stCode"].replace("Older than 85",85)

# %%
df4["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 5, '33', '25', '26', '39', '36', '38', '28', '31', 85,
#        '32', '37', '50', '65', '42', '34', '40', '67', '43', '44', '60',
#        '46', '45', '49', '51', '41', '55', '83', '48', '53', '54', '47',
#        '56', '79', '61', '68', '77', '66', '52', '80', '62', '84', '57',
#        '58', '63'], dtype=object)

# %%
df4.isnull().sum()
# Out:
# MainBranch          552
# Hobbyist              0
# OpenSourcer           0
# OpenSource         2041
# Employment         1702
# Country             132
# Student            1869
# EdLevel            2493
# UndergradMajor    13269
# EduOther           4623
# OrgSize           17092
# DeveloperType      7548
# YearsCode           945
# Age1stCode         1249
# YearsCodePro      14552
# CareerSat         16036
# JobSat            17895
# MgrIdiot          27724
# MgrMoney          27726
# MgrWant           27651
#                   ...
# SOVisitFreq         620
# SOVisitTo           797
# SOFindAnswer       1067
# SOTimeSaved        2539
# SOHowMuchTime     20505
# SOAccount          1055
# SOPartFreq        14191
# SOJobs              817
# EntTeams           1042
# SOComm              752
# WelcomeChange      3028
# SONewContent      19323
# Age                9673
# Gender             3477
# Trans              5276
# Sexuality         12736
# Ethnicity         12215
# ...

# %%
df4["SalaryUSD"].isnull().sum()
# Out:
# 33060

# %%
df4["SalaryUSD"].isnull().sum()/df4["SalaryUSD"].shape
# Out:
# array([0.37194964])

# %%
df4[df4["SalaryUSD"].isnull()]
# Out:
#                                                           MainBranch  \
# Respondent
# 1                             I am a student who is learning to code
# 2                             I am a student who is learning to code
# 5                                     I am a developer by profession
# 7                                     I am a developer by profession
# 8                                        I code primarily as a hobby
# 11                                       I code primarily as a hobby
# 12                            I am a student who is learning to code
# 15                            I am a student who is learning to code
# 21                                       I code primarily as a hobby
# 27          I used to be a developer by profession, but no longer am
# 28                                    I am a developer by profession
# 31                            I am a student who is learning to code
# ...

# %%
df4["Age1stCode"].fillna(df4['Age1stCode'].mode()[0],inplace=True)

# %%
df4["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', '27',
#        '24', 5, '33', '25', '26', '39', '36', '38', '28', '31', 85, '32',
#        '37', '50', '65', '42', '34', '40', '67', '43', '44', '60', '46',
#        '45', '49', '51', '41', '55', '83', '48', '53', '54', '47', '56',
#        '79', '61', '68', '77', '66', '52', '80', '62', '84', '57', '58',
#        '63'], dtype=object)

# %%
import numpy as np

# %%
df4["Age1stCode"].dtype
# Out:
# dtype('O')

# %%
df4["Age1stCode"]=df4["Age1stCode"].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 df4["Age1stCode"]=df4["Age1stCode"].astype("int64")
#
# File C:\hello world\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\hello world\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df4["Age1stCode"].dtype
# Out:
# dtype('O')

# %%
df4['Age1stCode']=df4['Age1stCode'].astype("int64")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 df4['Age1stCode']=df4['Age1stCode'].astype("int64")
#
# File C:\hello world\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\hello world\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df4["EdLevel"].isnull().sum()
# Out:
# 2493

# %%
df4=df4.dropna(subset=["EdLevel"])

# %%
df4["EdLevel"].isnull().sum()
# Out:
# 0

# %%
df4.sort_values(by="Country")
# Out:
#                                                                                MainBranch  \
# Respondent
# 48436                                                      I am a developer by profession
# 26340       I am not primarily a developer, but I write code sometimes as part of my work
# 10746                                                      I am a developer by profession
# 29045       I am not primarily a developer, but I write code sometimes as part of my work
# 22450                                                      I am a developer by profession
# 88731                                                         I code primarily as a hobby
# 6417                                               I am a student who is learning to code
# 60569                                              I am a student who is learning to code
# 63019                                                                                 NaN
# ...

# %%
df4.sort_values(by=["Country","Age"])
# Out:
#                                                                                MainBranch  \
# Respondent
# 62525                                              I am a student who is learning to code
# 80926                                              I am a student who is learning to code
# 47110                                                      I am a developer by profession
# 60569                                              I am a student who is learning to code
# 74386                                              I am a student who is learning to code
# 8149                                                       I am a developer by profession
# 10746                                                      I am a developer by profession
# 22450                                                      I am a developer by profession
# 48436                                                      I am a developer by profession
# ...

# %%
df4.sort_values(by="Country",ascending=False).loc[:50,['YearsCode',"Country"]]
# Out:
#            YearsCode   Country
# Respondent
# 84155              5  Zimbabwe
# 1886              11  Zimbabwe
# 61083              3  Zimbabwe
# 30743              6  Zimbabwe
# 55405             10  Zimbabwe
# 23162              1  Zimbabwe
# 83850              3  Zimbabwe
# 66459              9  Zimbabwe
# 51464              3  Zimbabwe
# 5110               5  Zimbabwe
# 51356              2  Zimbabwe
# 82752             14  Zimbabwe
# 77533              5  Zimbabwe
# 53047            NaN  Zimbabwe
# 2530               5  Zimbabwe
# 69495              5  Zimbabwe
# 3991               2  Zimbabwe
# 32960              5  Zimbabwe
# 57894              3  Zimbabwe
# 22363              8  Zimbabwe
# ...              ...       ...
# 88825              9     India
# 34883              7     India
# 33458              7     India
# 271                3     India
# 34906              7     India
# 34910             14     India
# 34916              9     India
# ...

# %%
df4.sort_values(by="Gender").loc[:50,['YearsCode',"Country",'Gender']]
# Out:
#            YearsCode             Country Gender
# Respondent
# 1                  4      United Kingdom    Man
# 58095             11           Australia    Man
# 58094              3             Germany    Man
# 58093             12       United States    Man
# 58092              8               Spain    Man
# 58091             48       United States    Man
# 58090             25      United Kingdom    Man
# 58089             20        Saudi Arabia    Man
# 58087              3      United Kingdom    Man
# 58086             14              France    Man
# 58084             12               India    Man
# 58083              9              Latvia    Man
# 58081             30       United States    Man
# 58080             10       United States    Man
# 58078              5  Russian Federation    Man
# 58077             26      United Kingdom    Man
# 58096             17      Czech Republic    Man
# 58076              5              France    Man
# ...
