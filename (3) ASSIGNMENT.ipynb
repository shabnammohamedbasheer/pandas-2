# %% [markdown]
# # ASSIGNMENT 31/07/2023

# %%
import pandas as pd

# %%
survey=pd.read_csv("survey_results_public.csv",index_col=[0])

# %%
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema=pd.read_csv("survey_results_schema.csv",index_col=[0])

# %%
schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %% [markdown]
# # (1) remove rows from 1000 to 1050

# %%
survey.drop(survey.loc[1000:1050].index,axis=0)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# # (2)Remove rows where Age is missing

# %%
survey["Age"].isnull()
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377     True
# 88601     True
# 88802     True
# 88816     True
# 88863    False
# Name: Age, Length: 88883, dtype: bool

# %%
age_null_value=survey.loc[(survey["Age"].isnull()==True),"Age"]

# %%
age_null_value
# Out:
# Respondent
# 10      NaN
# 18      NaN
# 21      NaN
# 28      NaN
# 31      NaN
#          ..
# 88282   NaN
# 88377   NaN
# 88601   NaN
# 88802   NaN
# 88816   NaN
# Name: Age, Length: 9673, dtype: float64

# %%
survey.drop(age_null_value.index)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 87352                                                     NaN      Yes
# 87386                                                     NaN      Yes
# 87739                                                     NaN      Yes
# 88212                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# # (3)Remove features about the personal info of developer

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema.loc["BetterLife","QuestionText"]
# Out:
# 'Do you think people born today will have a better life than their parents?'

# %%
survey.drop(["Age","Gender","Trans","Sexuality","BetterLife","Dependents"],axis=1)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# # (4)Remove developers who are 'Neither satisfied nor dissatisfied'

# %%
survey.value_counts("JobSat")
# Out:
# JobSat
# Slightly satisfied                    24207
# Very satisfied                        22452
# Slightly dissatisfied                 10752
# Neither satisfied nor dissatisfied     8720
# Very dissatisfied                      4857
# dtype: int64

# %%
jobsat=survey.loc[survey["JobSat"]=="Neither satisfied nor dissatisfied"]

# %%
jobsat
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 7                              I am a developer by profession       No
# 17                             I am a developer by profession      Yes
# 44                             I am a developer by profession      Yes
# 59                             I am a developer by profession      Yes
# 60                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88850                          I am a developer by profession      Yes
# 88856                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88881                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.drop(jobsat.index)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# # (5)Filter deveMopers who are looking forward to work with MySQL data base next year

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey["DatabaseDesireNextYear"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Respondent
# 1                                                    MySQL
# 2                                                    MySQL
# 3                                               PostgreSQL
# 4                                             MySQL;SQLite
# 5        Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#                                ...
# 88377                                Firebase;MySQL;SQLite
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863                          MariaDB;MySQL;Oracle;SQLite
# Name: DatabaseDesireNextYear, Length: 88883, dtype: object>

# %%
sql=survey["DatabaseDesireNextYear"].str.contains("MySQL",na=False)

# %%
sql
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: DatabaseDesireNextYear, Length: 88883, dtype: bool

# %%
sql1=survey.loc[sql,"DatabaseDesireNextYear"]

# %%
sql1
# Out:
# Respondent
# 1                                                    MySQL
# 2                                                    MySQL
# 4                                             MySQL;SQLite
# 5        Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 8        Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
#                                ...
# 85955             Microsoft SQL Server;MySQL;Oracle;SQLite
# 86806    Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 87739                                                MySQL
# 88377                                Firebase;MySQL;SQLite
# 88863                          MariaDB;MySQL;Oracle;SQLite
# Name: DatabaseDesireNextYear, Length: 25750, dtype: object

# %% [markdown]
# # (6) filter developers who got hired less than a year ago and let mw know their age and where are they actually from?

# %%
survey["LastHireDate"].unique
# Out:
# <bound method Series.unique of Respondent
# 1                         NaN
# 2        I've never had a job
# 3               1-2 years ago
# 4        Less than a year ago
# 5        Less than a year ago
#                  ...
# 88377                     NaN
# 88601                     NaN
# 88802                     NaN
# 88816                     NaN
# 88863                     NaN
# Name: LastHireDate, Length: 88883, dtype: object>

# %%
less_than_ayear=survey["LastHireDate"]=="Less than a year ago"

# %%
survey.loc[less_than_ayear,["Country","Age","LastHireDate"]]
# Out:
#                   Country   Age          LastHireDate
# Respondent
# 4           United States  22.0  Less than a year ago
# 5                 Ukraine  30.0  Less than a year ago
# 9             New Zealand  23.0  Less than a year ago
# 12                 Canada  21.0  Less than a year ago
# 17              Australia  29.0  Less than a year ago
# ...                   ...   ...                   ...
# 88871              Poland  22.0  Less than a year ago
# 88874       United States  26.0  Less than a year ago
# 88878       United States  26.0  Less than a year ago
# 88880       United States   NaN  Less than a year ago
# 88882         Netherlands   NaN  Less than a year ago
#
# [25844 rows x 3 columns]

# %% [markdown]
# # ASSIGNMENT 01/08/2023

# %% [markdown]
# # (1)Change column names of any 5 features

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey1=survey.copy()

# %%
survey1.rename(columns={"EdLevel":"Education","DevType":"DeveloperType","ConvertedComp":"SalaryUSD","JobSat":"JobSatisfaction","CareerSat":"CareerSatisfaction"},inplace=True)

# %%
survey1
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey1.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'Education', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DeveloperType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSatisfaction', 'JobSatisfaction', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'SalaryUSD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# # (2)Change Gender 'man' into Male and 'women' into Female

# %%
survey1["Gender"].unique()
# Out:
# array(['Male', nan, 'Female'], dtype=object)

# %%
survey1["Gender"]=survey1["Gender"].map({"Man":"Male","Woman":"Female"})

# %%
survey1["Gender"].unique()
# Out:
# array(['Male', nan, 'Female'], dtype=object)

# %% [markdown]
# # (3)Change all CurrencySymbol with CurrencyDesc

# %%
survey5=survey.copy()

# %%
survey5["CurrencyDesc"].unique()
# Out:
# array([nan, 'Thai baht', 'United States dollar', 'Ukrainian hryvnia',
#        'Canadian dollar', 'New Zealand dollar', 'Indian rupee',
#        'European Euro', 'Pound sterling', 'Australian dollar',
#        'Russian ruble', 'Brazilian real', 'Israeli new shekel',
#        'South African rand', 'Turkish lira', 'Swiss franc',
#        'Czech koruna', 'Malaysian ringgit', 'Polish zloty',
#        'Swedish krona', 'Chinese Yuan Renminbi', 'Argentine peso',
#        'Philippine peso', 'Pakistani rupee', 'Azerbaijan manat',
#        'Croatian kuna', 'South Korean won', 'Bulgarian lev',
#        'Vietnamese dong', 'Iranian rial', 'Hungarian forint',
#        'Hong Kong dollar', 'United Arab Emirates dirham',
#        'Nigerian naira', 'Norwegian krone', 'Danish krone',
#        'Japanese yen', 'CFP franc', 'Mexican peso', 'Egyptian pound',
#        'Mauritian rupee', 'Ugandan shilling', 'Saudi Arabian riyal',
#        'Sierra Leonean leone', 'Nicaraguan cordoba', 'Singapore dollar',
# ...

# %%
survey5["CurrencySymbol"].unique()
# Out:
# array([nan, 'THB', 'USD', 'UAH', 'CAD', 'NZD', 'INR', 'EUR', 'GBP', 'AUD',
#        'RUB', 'BRL', 'ILS', 'ZAR', 'TRY', 'CHF', 'CZK', 'MYR', 'PLN',
#        'SEK', 'CNY', 'ARS', 'PHP', 'PKR', 'AZN', 'HRK', 'KRW', 'BGN',
#        'VND', 'IRR', 'HUF', 'HKD', 'AED', 'NGN', 'NOK', 'DKK', 'JPY',
#        'XPF', 'MXN', 'EGP', 'MUR', 'UGX', 'SAR', 'SLL', 'NIO', 'SGD',
#        'NPR', 'AMD', 'RON', 'AFN', 'BHD', 'MNT', 'CLP', 'GEL', 'KES',
#        'DOP', 'BDT', 'CVE', 'RSD', 'BIF', 'LKR', 'IQD', 'COP', 'GTQ',
#        'TWD', 'YER', 'IDR', 'BYN', 'LYD', 'AOA', 'ALL', 'LBP', 'KWD',
#        'MDL', 'DZD', 'BAM', 'SYP', 'XOF', 'MAD', 'XAF', 'BND', 'MKD',
#        'JOD', 'TTD', 'ZMW', 'CRC', 'GHS', 'PYG', 'MMK', 'PEN', 'UZS',
#        'TND', 'HNL', 'QAR', 'RWF', 'KZT', 'TJS', 'UYU', 'TMT', 'TZS',
#        'KGS', 'SDG', 'ANG', 'SOS', 'GNF', 'ETB', 'KHR', 'CUP', 'MRU',
#        'BWP', 'BOB', 'ISK', 'DJF', 'VES', 'BZD', 'JMD', 'MVR', 'non',
# ...

# %%
survey6=survey5["CurrencySymbol"].replace(["THB","USD","UAH"],["Thai baht","United States dollar","Ukrainian hryvnia"])

# %%
survey6.value_counts()
# Out:
# United States dollar    19490
# EUR                     15386
# INR                      6690
# GBP                      4903
# CAD                      2680
#                         ...
# CVE                         1
# SCR                         1
# MWK                         1
# KYD                         1
# SOS                         1
# Name: CurrencySymbol, Length: 143, dtype: int64

# %%
survey6.unique()
# Out:
# array([nan, 'Thai baht', 'United States dollar', 'Ukrainian hryvnia',
#        'CAD', 'NZD', 'INR', 'EUR', 'GBP', 'AUD', 'RUB', 'BRL', 'ILS',
#        'ZAR', 'TRY', 'CHF', 'CZK', 'MYR', 'PLN', 'SEK', 'CNY', 'ARS',
#        'PHP', 'PKR', 'AZN', 'HRK', 'KRW', 'BGN', 'VND', 'IRR', 'HUF',
#        'HKD', 'AED', 'NGN', 'NOK', 'DKK', 'JPY', 'XPF', 'MXN', 'EGP',
#        'MUR', 'UGX', 'SAR', 'SLL', 'NIO', 'SGD', 'NPR', 'AMD', 'RON',
#        'AFN', 'BHD', 'MNT', 'CLP', 'GEL', 'KES', 'DOP', 'BDT', 'CVE',
#        'RSD', 'BIF', 'LKR', 'IQD', 'COP', 'GTQ', 'TWD', 'YER', 'IDR',
#        'BYN', 'LYD', 'AOA', 'ALL', 'LBP', 'KWD', 'MDL', 'DZD', 'BAM',
#        'SYP', 'XOF', 'MAD', 'XAF', 'BND', 'MKD', 'JOD', 'TTD', 'ZMW',
#        'CRC', 'GHS', 'PYG', 'MMK', 'PEN', 'UZS', 'TND', 'HNL', 'QAR',
#        'RWF', 'KZT', 'TJS', 'UYU', 'TMT', 'TZS', 'KGS', 'SDG', 'ANG',
#        'SOS', 'GNF', 'ETB', 'KHR', 'CUP', 'MRU', 'BWP', 'BOB', 'ISK',
# ...

# %% [markdown]
# # (4)replace developers who earns more than 1900000 into 1900000

# %%
survey7=survey.copy()

# %%
survey7.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey7["ConvertedComp"].dropna()
# Out:
# Respondent
# 3          8820.0
# 4         61000.0
# 6        366420.0
# 9         95179.0
# 10        13293.0
#            ...
# 88878    130000.0
# 88879     82488.0
# 88881     68745.0
# 88882    588012.0
# 88883     22915.0
# Name: ConvertedComp, Length: 55823, dtype: float64

# %%
survey7["ConvertedComp"][survey7["ConvertedComp"]>1900000]=1900000
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13088\707919606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey7["ConvertedComp"][survey7["ConvertedComp"]>1900000]=1900000

# %% [markdown]
# # (5)Fill all the nan values of WorkingLocation with appropriate values

# %%
survey1["WorkLoc"].fillna(survey1["WorkLoc"].mode()[0],inplace=True)

# %%
survey1["WorkLoc"].unique()
# Out:
# array(['Office', 'Home', 'Other place, such as a coworking space or cafe'],
#       dtype=object)

# %%
survey1["WorkLoc"].value_counts()
# Out:
# Office                                            59420
# Home                                              23278
# Other place, such as a coworking space or cafe     6185
# Name: WorkLoc, dtype: int64

# %%
survey["WorkLoc"].value_counts()
# Out:
# Office                                            40592
# Home                                              23278
# Other place, such as a coworking space or cafe     6185
# Name: WorkLoc, dtype: int64

# %%
survey1["WorkLoc"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # (6)If developer started his coding less than 10 years of age and if they are not getting any combensation give them 1 Lakh

# %%
survey3=survey.copy()

# %%
survey3["Age1stCode"].unique()
# Out:
# array(['10', '17', '22', '16', '14', '15', '11', '20', '13', '18', '12',
#        '19', '21', '8', '35', '6', '9', '29', '7', '5', '23', '30', nan,
#        '27', '24', 'Younger than 5 years', '33', '25', '26', '39', '36',
#        '38', '28', '31', 'Older than 85', '32', '37', '50', '65', '42',
#        '34', '40', '67', '43', '44', '60', '46', '45', '49', '51', '41',
#        '55', '83', '48', '53', '54', '47', '56', '79', '61', '68', '77',
#        '66', '52', '80', '62', '84', '57', '58', '63'], dtype=object)

# %%
survey3["Age1stCode"].replace("Older than 85",85,inplace=True)

# %%
survey3["Age1stCode"].replace("Younger than 5 years",5,inplace=True)

# %%
survey3["Age1stCode"]=survey3["Age1stCode"].astype("int64")

# %%
survey3["Age1stCode"].unique()
# Out:
# array([10, 17, 22, 16, 14, 15, 11, 20, 13, 18, 12, 19, 21,  8, 35,  6,  9,
#        29,  7,  5, 23, 30, 27, 24, 33, 25, 26, 39, 36, 38, 28, 31, 85, 32,
#        37, 50, 65, 42, 34, 40, 67, 43, 44, 60, 46, 45, 49, 51, 41, 55, 83,
#        48, 53, 54, 47, 56, 79, 61, 68, 77, 66, 52, 80, 62, 84, 57, 58, 63],
#       dtype=int64)

# %%
survey3.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey3.loc[:,["Age1stCode","CompTotal"]]
# Out:
#             Age1stCode  CompTotal
# Respondent
# 1                   10        NaN
# 2                   17        NaN
# 3                   22    23000.0
# 4                   16    61000.0
# 5                   14        NaN
# ...                ...        ...
# 88377               15        NaN
# 88601               15        NaN
# 88802               15        NaN
# 88816               15        NaN
# 88863               11        NaN
#
# [88883 rows x 2 columns]

# %%
less10=survey3.loc[(survey3["Age1stCode"]<10),["Age1stCode","CompTotal"]]

# %%
less10
# Out:
#             Age1stCode  CompTotal
# Respondent
# 26                   8   114000.0
# 39                   6   156000.0
# 51                   9        NaN
# 52                   8    12320.0
# 63                   7        NaN
# ...                ...        ...
# 85642                7        NaN
# 85738                5        NaN
# 85955                9        NaN
# 88182                5        NaN
# 88212                7        NaN
#
# [7661 rows x 2 columns]

# %%
filcomp=less10["CompTotal"].fillna(100000)

# %%
filcomp
# Out:
# Respondent
# 26       114000.0
# 39       156000.0
# 51       100000.0
# 52        12320.0
# 63       100000.0
#            ...
# 85642    100000.0
# 85738    100000.0
# 85955    100000.0
# 88182    100000.0
# 88212    100000.0
# Name: CompTotal, Length: 7661, dtype: float64

# %%
filcomp.isnull().sum()
# Out:
# 0

# %%
less10["CompTotal"].replace(0,100000)
# Out:
# Respondent
# 26       114000.0
# 39       156000.0
# 51       100000.0
# 52        12320.0
# 63       100000.0
#            ...
# 85642    100000.0
# 85738    100000.0
# 85955    100000.0
# 88182    100000.0
# 88212    100000.0
# Name: CompTotal, Length: 7661, dtype: float64

# %%
less10["CompTotal"].value_counts()
# Out:
# 100000.0     3000
# 60000.0       120
# 120000.0      102
# 50000.0       101
# 150000.0      101
#              ...
# 198000.0        1
# 1420.0          1
# 68400.0         1
# 9500000.0       1
# 2860000.0       1
# Name: CompTotal, Length: 885, dtype: int64

# %% [markdown]
# # (7)Fill nan of jos satisfaction with the condition of most developers

# %%
survey1["JobSatisfaction"].unique()
# Out:
# array([nan, 'Slightly satisfied', 'Slightly dissatisfied',
#        'Neither satisfied nor dissatisfied', 'Very satisfied',
#        'Very dissatisfied'], dtype=object)

# %%
survey1["JobSatisfaction"].isnull().sum()
# Out:
# 17895

# %%
survey1["JobSatisfaction"].fillna(survey1["JobSatisfaction"].mode()[0],inplace=True)

# %%
survey1["JobSatisfaction"].isnull().sum()
# Out:
# 0

# %%
survey1["JobSatisfaction"].value_counts()
# Out:
# Slightly satisfied                    32435
# Very satisfied                        18839
# Slightly dissatisfied                  8677
# Neither satisfied nor dissatisfied     6538
# Very dissatisfied                      3827
# Name: JobSatisfaction, dtype: int64

# %% [markdown]
# # (8)Change data type of YearsCode into float64 (do all the required operations)

# %%
survey1["YearsCode"].dtype
# Out:
# dtype('O')

# %%
survey1["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
survey1["YearsCode"].replace("Less than 1 year",5,inplace=True)

# %%
survey1["YearsCode"].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 5, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37',
#        'More than 50 years', '29', '44', '45', '48', '46', '43', '47',
#        '49'], dtype=object)

# %%
survey1["YearsCode"].replace("More than 50 years",50,inplace=True)

# %%
survey1["YearsCode"].unique()
# Out:
# array([15.,  3.,  6.,  5., 10., 20., 24., 29., 31., 25., 11., 34., 39.,
#        40., 35., 30., 37., 38., 36.,  4., 32., 41.,  2., 45., 48., 46.,
#        43., 18., 23., 42., 47., 12., 27., 50.,  1., 49., 33., nan, 44.,
#        28.,  7., 21.,  8.,  9., 13., 14., 16., 17., 19., 22., 26.])

# %%
survey1["YearsCode"]=survey1["YearsCode"].astype("float64")

# %%
survey1["YearsCode"].unique()
# Out:
# array([15.,  3.,  6.,  5., 10., 20., 24., 29., 31., 25., 11., 34., 39.,
#        40., 35., 30., 37., 38., 36.,  4., 32., 41.,  2., 45., 48., 46.,
#        43., 18., 23., 42., 47., 12., 27., 50.,  1., 49., 33., nan, 44.,
#        28.,  7., 21.,  8.,  9., 13., 14., 16., 17., 19., 22., 26.])

# %%
survey1["YearsCode"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # (9)Drop nan values of Ethnicity and Sexuality in a single operation

# %%
survey1.dropna(subset=["Ethnicity","Sexuality"],inplace=True)

# %%
survey1["Sexuality"].isnull().sum()
# Out:
# 0

# %%
survey1["Ethnicity"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # (10)Sort values by Employment and Age

# %%
survey1.sort_values(["Employment","Age"],ascending=[False,True],inplace=True)

# %%
survey1
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 22168                                          NaN       No
# 43897                                          NaN      Yes
# 61765                  I code primarily as a hobby      Yes
# 70090       I am a student who is learning to code       No
# 73419               I am a developer by profession      Yes
# ...                                            ...      ...
# 55452                                          NaN       No
# 61029                                          NaN      Yes
# 64465                                          NaN      Yes
# 68208                                          NaN      Yes
# 76822                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 22168                              Once a month or more often
# 43897                                                   Never
# ...
